# %%
import numpy as np
import pandas as pd
data = {
    'S_no' :  [1,2],
    'E-mail' : ['yashwalker01625@gmail.com','yashhh1244@gmail.com'],
    'Password' :['Yash@123','Yashhh@123']                                                         #dataframe that stores the sign in credentials of users
}

cart_items = []

def cart(product_name=None, price=None):
    print("\na. Add to cart\nb. Back")                                                                        #function which will stores items which are selected
    choose = input("Enter your choice (Add or Back): ").strip().lower()
    if choose == 'add' and product_name is not None and price is not None:
        cart_items.append((product_name, price))
        print(f" '{product_name}' has been added to your cart for Rs.{price}\n")
    elif choose == 'back':
        print(" Back to the previous tab\n")
    else:
        print(" Invalid input or missing product info\n")


def checkout():
    if not cart_items:
        print("\n Your cart is empty.\n")
        return
    print("\n Items in your cart:")                                                                           #function which will display items and their total worth
    total = 0
    for item, price in cart_items:
        print(f" {item} - Rs.{price}")
        total += price
    print(f"\n Total amount to pay: Rs.{total}\n")

data_frame = pd.DataFrame(data)
print("\t\t***Welcome to Amazon Online Shopping!!!***")
print()

def signin():
  e=input("Enter your email address: ")
  p=input("Enter your password: ")
  user_match = data_frame[                                                                                        # function for sign in
      (data_frame['E-mail'] == e) & (data_frame['Password'] == p)
  ]
  if not user_match.empty:
    print("\nLogin Succesful!")
    return True
  else:
    print("\nInvalid E-mail or password. Please try again.")
    return False

def signup():
  authentication = False
  print("\nLet's create one!!!")
  email=input("Enter your email: ")
  password=input("Enter your password: ")                                                                         #function for sign up
  re_password=input("Re-enter your password: ")
  if password == re_password:
    print("\nSign up successful!")
    return True
  else:
    print("\nPassword doesn't match. Please try again.")
    return False

authenticated = False                                                                         #Checks whether the credentials are correct else not moving forward

while not authenticated:
    account_input = input("Do you have an account? (True/False): ").strip().lower()

    if account_input == 'true':
        authenticated = signin()
    elif account_input == 'false':
        authenticated = signup()
    else:
        print("Invalid input. Please enter 'True' or 'False'.")

while True:

 print("\n\t\t\t****WELCOME TO AMAZON****\n")
 print("What are you searching for:\n1.Electronics\n2.Fashion\n3.Groceries\n4.Checkout\n5.Exit")                            #Categories available
 print()
 category=input("Enter your choice: ")

 if category in ['Electronics','1']:
  while True:


    print("\n1.Mobiles\n2.Tablets\n3.Speakers\n4.Headphones\n5.Laptops\n6.Checkout\n7.Back")                                #iplementing nested if/else statements
    print()
    item=input("Enter you whish to browse: ")

    if item in ['Mobiles','1']:
      while True:
       print("\ni.Iphone 14\nii.Iphone 16 Pro Max\niii.Nothing Phone 1\niv.Redmi Note 12 Pro\nv.One Plus Nord\nvi.ROG Phone 5\nvii.Back")
       print()
       mob=input("Enter the name you want to purchase:")
       if mob in ['Iphone 14','i']:
         product_name="\nIphone 14, 256 GB, Baby-Pink"
         price=66000
         print("/n",product_name)
         print("Price: Rs. ",price)
         cart(product_name, price)

       elif mob in['Iphone 16 Pro Max','ii']:
         product_name="\nIphone 16 Pro Max, 1TB, Space-Grey"
         price=180000
         print("\n",product_name)
         print("price: Rs. ",price)
         cart(product_name,price)

       elif mob in ['Nothing Phone 1','iii']:
         product_name="\nNothing Phone 1, 256 GB, Black"
         price=42000
         print("\n",product_name)
         print("Price: Rs. ",price)
         cart(product_name,price)

       elif mob in ['Redmi Note 12 Pro','iv']:
         product_name="\nRedmi Note 12 pro, 128 GB, Black-Nebula"
         price=20000
         print("\n",product_name)
         print("Price: Rs. ",price)
         cart(product_name,price)

       elif mob in ['One Plus Nord','v']:
         product_name="\nOne Plus Nord, 128 GB, Grey"
         price=50000
         cart(product_name,price)

       elif mob in ['ROG Phone 5','vi']:
         product_name="\nROG Phone 5, 256 GB, White"
         price=60000
         cart(product_name,price)

       elif mob in['Back','vii']:
         print("\nBack to the previous menu...")
         break
       else:
         print("\nSorry! We don't have this product available")

    elif item in ['Tablets','2']:
      while True:

       print("\ni.One Plus Pad Go\nii.Lenovo Tab M11\niii.Redmi Pad SE\niv.Samsung Galaxy Tab S9 FE\nv.One Plus Pad 2\nvi.Apple I-Pad 11th Gen\nvii.Back")
       print()
       tablet=input("Enter your choice: ")
       if tablet in ['One Plus Pad Go','i']:
         product_name="\nOne Plus Pad Go, 128 GB, Grey"
         price=17000
         cart(product_name,price)

       elif tablet in ['Lenovo Tab M11','ii']:
         product_name="\nLenovo Tab M11, 128 GB, Frost-White"
         price=20000
         cart(product_name,price)

       elif tablet in ['Redmi Pad SE','iii']:
         product_name="\nRedmi Pad SE, 128 GB, Black"
         price=19000
         cart(product_name,price)

       elif tablet in ['Samsung Galaxy Tab S9 FE','iv']:
         product_name="\nSamsung Galaxy Tab S9 FE, 256 GB, Midnight-Blue"
         price=30000
         cart(product_name,price)

       elif tablet in ['One Plus Pad 2','v']:
         product_name="\nOne Plus Pad 2,128 GB, Space-Grey"
         price=25000
         cart(product_name,price)

       elif tablet in ['Apple I-Pad 11th Gen','vi']:
         product_name="\nApple I-Pad 11th Gen, 256 GB, Baby-Pink"
         price=80000
         cart(product_name,price)

       elif tablet in ['Back','vii']:
         print("\nReturning to previous page.")
         break
       else:
         print("\nSorry! We don't have this product available")


    elif item in ['Speakers','3']:
      while True:
       print("\ni.JBL GO 2\nii.SONY SRS-SV500\niii.Bose Soundlink Home\niv.Beats Pill\nv.Marshall Action II\nvi.Boult Bassbox X500\nviiSoundcore Select 4 GO\nviii.Back")
       print()
       speaker=input("Enter you want to purchase: ")
       if speaker in ['JBL GO 2','i']:
          product_name="\nJBL GO 2, Black"
          price=1999
          cart(product_name,price)

       elif speaker in ["SONY SRS-SV500",'ii']:
          product_name="\nSONY SRS-SV500, Grey"
          price=29500
          cart(product_name,price)

       elif speaker in ['Bose Soundlink Home','iii']:
          product_name="\nBose Soundlink Home, White"
          price=18000
          cart(product_name,price)

       elif speaker in ['Beats Pill','iv']:
          product_name="\nBeats Pill, Blue"
          prie=16900
          cart(product_name,price)

       elif speaker in ['Marshall Action II','v']:
          product_name="\nMarshall Action II, Classic-Black"
          price=24999
          cart(product_name,price)

       elif speaker in ['Boult Bassbox X500','vi']:
          product_name="\nBoult Bassbox X500, Black"
          price=15000
          cart(product_name,price)

       elif speaker in ['Sound Core Select 4 GO','vii']:
          product_name="\nSound Core Select 4 GO, Two-Tone Black"
          price=2400
          cart(product_name,price)

       elif speaker in ['Back','viii']:
          print("\nReturning to previous page.")
          break
       else:
        print("\nSorry! We don't have this product available")

    elif item in ['Headphones','4']:
      while True:
       print("\ni.Beats Pro\nii.Beats Solo 2\niii.Logitech G633\niv.Sony MDR-ZX110AP\nv.Sony WH-XB900N\nvi.JBL E45BT\nvii.Back")
       print()
       headphone=input("Enter you want to purchase: ")
       if headphone in['Beats Pro','i']:
        product_name="\nBeats Pro, Black"
        price=33300
        cart(product_name,price)

       elif headphone in ['Beats Solo 2','ii']:
        product_name="\nBeats Solo 2, Blue"
        price=16990
        cart(product_name,price)

       elif headphone in ['Logitech G633','iii']:
        product_name="\nLogitech G633, Black with RGB-lighting"
        price=12495
        cart(product_name,price)

       elif headphone in ['Sony MDR-ZX110AP','iv']:
        product_name="\nSony MDR-ZX110AP, White"
        price=1390
        cart(product_name,price)

       elif headphone in ['Sony WH-XB900N','v']:
        product_name="\nSony WH-XB900N, Cameo"
        price=16990
        cart(product_name,price)

       elif headphone in ['JBL E45BT','vi']:
        product_name="\nJBL E45BT, Red"
        price=3651
        cart(product_name,price)

       elif headphone in ['Back','vii']:
        print("\nReturning to previous page.")
        break
       else:
        print("\nSorry! We don't have this product available")


    elif item in ['Laptops','5']:
      while True:
        print("\ni.Lenovo Ideapad Gaming 3\nii.HP Victus\niii.Acer Predator Helios Neo 16\niv.HP Omen\nv.Asus TUF Gaming\nvi.Asus Zephyrus M16\nvii.Back")
        print()
        lap=input("Enter the product you want to purchase: ")
        if lap in ['Lenovo Ideapad Gaming 3','i']:
          product_name="\nLenovo Ideapad Gaming 3, i5 11th Gen processor, 512 GB SSD, GTX 1640, 14.6 inch display"
          price=55999
          cart(product_name,price)

        elif lap in ['HP Victus','ii']:
          product_name="\nHP Victus, i7 11th Gen processor, 512 GB SSD, RTX 4050, 16 inch display"
          price=80000
          cart(product_name,price
               )
        elif lap in ['Acer Predator Helios Neo 16','iii']:
          product_name="\nAcer Predator Helios Neo 16, i9 14th Gen processor, 1TB SSD, RTX 4070, 16 inch display"
          price=174999
          cart(product_name,price)

        elif lap in ['HP Omen','iv']:
          product_name="\nHP Omen, Ryzen 7, 1 TB SSD, RTX 3060, 15.6 inch display"
          price=128000
          cart(product_name,price)

        elif lap in ['Asus TUF Gaming','v']:
          product_name="\nAsus TUF Gaming, Ryzen 7, 512 GB SSD, RTX 3060, 16 inch display"
          price=80000
          cart(product_name,price)

        elif lap in ['Asus Zephyrus M16','vi']:
          product_name="\nAsus Zephyrus M16, i9 12th Gen, 1 TB SSD, RTX 3070, 16 inch display"
          price=241999
          cart(product_name,price)

        elif lap in ['Back','vii']:
          print("\nReturning to previous page.")
          break
        else:
          print("\nSorry! We don't have this product available")

    elif item in ['Checkout','6']:
      checkout()

    elif item in ['Back','7']:
      print("Returning to previous page.")
      break

 elif category in ['Fashion','2']:
  while True:
    print("For whom are you looking for:\na.Men\nb.Women\nc.Kids\nd.Checkout\ne.Back")
    print()
    age=input("Enter for whom you want to proceed: ")
    if age in ['Men','a']:
      while True:
        print("\nHere is our collection:\ni.T-shirts\nii.Jeans\niii.Shoes\niv.Shades\nv.Back")
        print()
        men=input("Enter your choice: ")
        if men in ['T-shirts','i']:
          while True:
            print("\n1.Mens Puma Slim Fit\n2.Celio Mens t-shirt\n3.Bullmer Black Men\n4.Wrogen Men Black\n5.Peter England Mens Green\n6.Back")
            print()
            tshirt=input("Enter you want to purchase: ")
            if tshirt in ['Mens Puma Slim','1']:
              product_name="\nMens Puma Slim, Black"
              price=799
              cart(product_name,price)

            elif tshirt in ['Celio Mens t-shirt','2']:
              product_name="\nCelio Mens t-shirt, Nardo-Grey"
              price=699
              cart(product_name,price)

            elif tshirt in ['Bullmer Black Men','3']:
              product_name="\nBullmer Black Men, Off-White"
              price=599
              cart(product_name,price)

            elif tshirt in ['Wrogen Men Black','4']:
              product_name="\nWrogen Men Black, Navy-Blue"
              price=650
              cart(product_name,price)

            elif tshirt in ['Peter England Mens Green','5']:
              product_name="\nPeter England Mens Green, Light-Brown"
              price=500
              cart(product_name,price)

            elif tshirt in ['Back','6']:
              print("\nReturning to previous page.")
              break
            else:
              print("\nSorry! We don't have this product available")


        elif men in ['Jeans','ii']:
          while True:
            print("\n1.Levis Men\n2.Calvin Kelvin Jeans Men\n3.Peter England Jeans\n4.Rigo Men Slim\n5.Jack & Jones Men\n6.Back")
            print()
            jean=input("Enter you want to purchase: ")
            if jean in ['Levis Men ','1']:
              product_name="\nLevis Men, Blue"
              price=1300
              cart(product_name,price)

            elif jean in ['Calvin Kelvin Jeans Men','2']:
              product_name="\nCalvin Kelvin Jeans Men, Black"
              price=1600
              cart(product_name,price)

            elif jean in ['Peter England Jeans','3']:
              product_name="\nPeter England Jeans, Blue"
              price=2000
              cart(product_name,price)

            elif jean in ['Rigo Men Slim','4']:
              product_name="\nRigo Men Slim, White"
              price=1500
              cart(product_name,price)

            elif jean in ['Jack & Jones','5']:
              product_name="\nJack & Jones, Black"
              price=1800
              cart(product_name,price)

            elif jean in ['Back','6']:
              print("\nReturning to the previous page.")
              break
            else:
              print("\nSorry! We don't have this product available")


        elif men in ['Shoes','iii']:
          while True:
            print("\n1.Nike Air Force-1\n2.Mens Puma Electron\n3.Mens Puma Robust\n4.Nike Air Jordan-1 Retro\n5.Sketchers Veroma\n6.Sketchers Men Arch\n7.Back")
            print()
            shoe=input("Enter you want to purchase: ")
            if shoe in ['Nike Air Force-1','1']:
              product_name="\nNike Air Force-1, Black"
              price=7495
              cart(product_name,price)

            elif shoe in ['Mens Puma Electon','2']:
              product_name="\nMens Puma Electron, Black-Lake-Blue"
              price=5599
              cart(product_name,price)

            elif shoe in ['Mens Puma Robust','3']:
              product_name="\nMens Puma Robust, Ultra-Grey-Yellow Alert"
              price=2499
              cart(product_name,price)

            elif shoe in ['Nike Air Jordan-1 Retro','4']:
              product_name="\nNike Air Jordan-1, Black-N-Gold"
              price=16995
              cart(product_name,price)

            elif shoe in ['Sketchers Veroma','5']:
              product_name="\nSketchers Veroma, White"
              price=5999
              cart(product_name,price)

            elif shoe in ['Sketchers Men Arch','6']:
              product_name="\nSketchers Men Arch, Black"
              price=6599
              cart(product_name,price)

            elif shoe in ['Back','7']:
              print("\nReturning to previous page.")
              break
            else:
              print("\nSorry! We don't have this product available")


        elif men in ['Shades','iv']:
          while True:
            print("\n1.Clarton London Men\n2.Hugo Boss\n3.Marc Jacobs\n4.Louis Vuitton Hit Sunglasses\n5.NuVew\n6.Back")
            print()
            shade=input("Enter you want to purchase: ")
            if shade in ['Clarton London Men','1']:
              product_name="\nClarton London Men, Blue"
              price=999
              cart(product_name,price)

            elif shade in ['Hugo Boss','2']:
              product_name="\nHugo Boss, Brown"
              price=789
              cart(product_name,price)

            elif shade in ['Marc Jacobs','3']:
              product_name="\nMarc Jacobs, Black"
              price=3299
              cart(product_name,price)

            elif shade in ['Louis Vuitton Hit Sunglasses','4']:
              product_name="\nLouis Vuitton Hit Sunglasses, Green"
              price=37500
              cart(product_name,price)

            elif shade in ['NuVew','5']:
              product_name="\nNuVew, Black"
              price=500
              cart(product_name,price)

            elif shade in ['Back','6']:
              print("\nReturning to previous page.")
              break
            else:
              print("\nSorry! We don't have this product available")


        elif men in ['Back','v']:
          print("returning to previous page.")
          break
        else:
          print("Invalid characters. Enter your choice again.")
    elif age in ['Women','b']:
      while True:
        print("\nHere is our collection\ni.Tops\nii.Jeans\niii.Shoes\niv.Shades\nvi.Back")
        print()
        women=input("Enter your choice: ")
        if women in ['Tops','i']:
         while True:
           print("\n1.Abstract Cotton Blend V-Neck\n2.Van Heusen Half-Sleeve\n3.Max Women Fit Top\n4.Leriya Fashion Top\n5.Kotty Women Sleeveless\n6.Back")
           print()
           top=input("Enter you want to purchase: ")
           if top in ['Abstract cotton Blend V-Neck','1']:
            product_name="\nAbstract Cotton Blend V-Neck, Navy-Blue"
            price=699
            cart(product_name,price)

           elif top in ['Van Heusen Half-Sleeve','2']:
            product_name="\nVan Heusen Half-Sleeve, Black"
            price=599
            cart(product_name,price)

           elif top in ['Max Women Fit Top','3']:
            product_name="\nMax Women Fit Top, Frost-White"
            price=749
            cart(product_name,price)

           elif top in ['Leriya Fashion Top','4']:
            product_name="\nLeriya Fashion Top, Brown"
            price=649
            cart(product_name,price)

           elif top in ['Kotty Women Sleeveless','5']:
            product_name="\nKotty Women Sleeveless, Black-White"
            price=799
            cart(product_name,price)

           elif top in ['Back','6']:
            print("\nReturning to previous page.")
            break
           else:
            print("\nSorry! We don't have this product available")


        elif women in ['Jeans','ii']:
          while True:
            print("\n1.Stylecast Women Heavy Fade\n2.Roadster Women Bootcut\n3.H&M Women Straight Jeans\n4.Cotty Women Straight Fit\n5.IVOC Women Cotton Cargo\n6.Back")
            print()
            w_jean=input("Enter you want to purchase: ")
            if w_jean in ['Stylecast Women Heavy Fade','1']:
              product_name="\nStylecast Women Heavy Fade, Dark-Blue"
              price=1499
              cart(product_name,price)

            elif w_jean in ['Roadster Women Bootcut','2']:
              product_name="\nRoadster Women Bootcut, Black"
              price=1799
              cart(product_name,price)

            elif w_jean in ['H&M Women Straight Jeans','3']:
              product_name="\nH&M Women Straight Jeans, Light-Blue"
              price=1599
              cart(product_name,price)

            elif w_jean in ['Cotty Women Straight Fit','4']:
              product_name="\nCotty Women Straight Fit, Navy-Blue"
              price=1899
              cart(product_name,price)

            elif w_jean in ['IVOC Women Cotton Cargo','5']:
              product_name="\nIVOC Women Catton Cargo, Cameo"
              price=2199
              cart(product_name,price)

            elif w_jean in ['Back','6']:
              print("\nReturning to previous page.")
              break
            else:
              print("\nSorry! We don't have this product available")


        elif women in ['Shoes','iii']:
          while True:
            print("\n1.Puma Robbin Sneakers\n2.Sparxx Women SL\n3.Bacca Bucci Women Savage\n4.Nike Court Vision Alta\n5. Nike Air Jordan 4 RM\n6.Back")
            print()
            w_shoe=input("Enter you want to purchase: ")
            if w_shoe in ['Puma Robbin Sneakers','1']:
              product_name="\nPuma Robbin Sneakers, Nitro-Blue"
              price=2199
              cart(product_name,price)

            elif w_shoe in ['Sparxx Women SL','2']:
              product_name="\nSparxx Women SL, Black-Peach"
              price=849
              cart(product_name,price)

            elif w_shoe in ['Bacca Bucci Women Savage','3']:
              product_name="\nBacca Bucci Women Savage, Black"
              price=1499
              cart(product_name,price)

            elif w_shoe in ['Nike Court Vision Alta','4']:
              product_name="\nNike Court Vision Alta, White"
              price=7095
              cart(product_name,price)

            elif w_shoe in ['Nike Air Jordan 4 RM','5']:
              product_name="\nNike Air Jordan 4 RM, Grey-White"
              price=12795
              cart(product_name,price)

            elif w_shoe in ['Back','6']:
              print("\nReturning to previous page.")
              break
            else:
              print("\nSorry! We don't have this product available")


        elif women in ['Shades','iv']:
          while True:
            print("\n1.Fasttrack Round Sunglasses\n2.AUGEN Oval\n3.Creek Retro Oval\n4.Voyage Cat-eye Sunglasses\n5.Dervin Retro Oval Sunglasses\n6.Back")
            print()
            w_shade=input("Enter you want to purchase: ")
            if w_shade in ['Fasttrack Round Sunglasses','1']:
              product_name="\nFasttrack Round Sunglasses, Blue"
              price=1349
              cart(product_name,price)

            elif w_shade in ['AUGEN Oval','2']:
              product_name="\nAUGEN Oval, Cyan"
              price=449
              cart(product_name,price)

            elif w_shade in ['Creek Retro Oval','3']:
              product_name="\nCreek Retro Oval, Black"
              price=472
              cart(product_name,price)

            elif w_shade in ['Voyage Cat-eye Sunglasses','4']:
              product_name="\nVoyage Cat-eye Sunglasses, Black"
              price=645
              cart(product_name,price)

            elif w_shade in ['Dervin Retro Oval Sunglasses','5']:
              product_name="\nDervin Retro Oval Sunglasses, Blue"
              price=500
              cart(product_name,price)

            elif w_shade in ['Back','6']:
              print("\nReturning to previous page.")
              break
            else:
              print("\nSorry! We don't have this product available")


        elif women in ['Back','vi']:
          print("returning to previous page.")
          break
        else:
          print("Invalid characters. Enter your choice again.")

    elif age in ['Kids','c']:
      while True:
        print("\nHere is our collection\ni.T-shirt\nii.Jeans\niii.Shoes\niv.Shades\nv.Back")
        print()
        kid=input("Enter your choice: ")
        if kid in ['T-shirt','i']:
          while True:
            print("\n1.Kidonik Boys T-shirt\n2.Sakurya Kids T-shirt\n3.Hellcat Cotton Half-Sleeves\n4.Pilolo T-shirt\n5.Back")
            print()
            k_tshirt=input("Enter you want to purchase: ")
            if k_tshirt in ['Kidonik Boys T-shirt','1']:
              product_name="\nKidonik Boys T-shirt, Yellow"
              price=549
              cart(product_name,price)

            elif k_tshirt in ['Sakurya Kids T-shirt','2']:
              product_name="\nSakurya Kids T-shirt, Pink"
              price=1499
              cart(product_name,price)

            elif k_tshirt in ['Hellcat Cotton Half-Sleeves','3']:
              product_name="\nHellcat Cotton Half-Sleeves, Cyan"
              price=499
              cart(product_name,price)

            elif k_tshirt in ['Pilolo T-shirt','4']:
              product_name="\nPilolo T-shirt, Purple"
              price=699
              cart(product_name,price)

            elif k_tshirt in ['Back','5']:
              print("\nReturning to previous page.")
              break
            else:
              print("\nSorry! We don't have this product available.")
        elif kid in ['Jeans','ii']:
          while True:
            print("\n1.Urbano Juniors\n2.Parilux Denim\n3.Allen Solly Slim Jeans\n4.Hopscotch Cotton Jeans\n5.Back")
            print()
            k_jean=input("Enter you want to purchase: ")
            if k_jean in ['Urbano Juniors','1']:
              product_name="\nUrbano Juniors, Blue"
              price=469
              cart(product_name,price)

            elif k_jean in ['Parilux Denim','2']:
              product_name="\nParilux Denim Jeans, Blue"
              price=499
              cart(product_name,price)

            elif k_jean in ['Allen Solly Slim Jeans','3']:
              product_name="\nAllen Solly Slim Jeans, Black"
              price=805
              cart(product_name,price)

            elif k_jean in ['Hopscotch Cotton Jeans','4']:
              product_name="\nHopscotch Cotton Jeans, Light-BLue"
              price=699
              cart(product_name,price)

            elif k_jean in ['Back','5']:
              print("\nReturning to previous page.")
              break
            else:
              print("\nSorry! We don't have this product available")


        elif kid in ['Shoes','iii']:
          while True:
            print("\n1.AREETO Kids Shoes\n2.Asian Casual Sneakers\n3.Liberty Kids Sports Shoes\n4.Puma Unisex-Kids Sneakers\n5.Nike Jordan 3 Retro\n6.Back")
            print()
            k_shoe=input("Enter you want to purchase: ")
            if k_shoe in ['AREETO Kids Shoes','1']:
              product_name="\nAREETO Kids Shoes, White"
              price=1599
              cart(product_name,price)

            elif k_shoe in ['Asian Casual Sneakers','2']:
              product_name="\nAsian Casual Shoes, Yellow-Blue"
              price=1399
              cart(product_name,price)

            elif k_shoe in ['Liberty Kids Sports Shoes','3']:
              product_name="\nLiberty Kids Sports Shoes, Black"
              price=2000
              cart(product_name,price)

            elif k_shoe in ['Puma Unisex-Kids Sneakers','4']:
              product_name="\nPuma Unisex-Kids Sneakers, Purple-White"
              price=2349
              cart(product_name,price)

            elif k_shoe in ['Nike Jordan 3 Retro','5']:
              product_name="\nNike Jordan 3 Retro, White"
              price=5095
              cart(product_name,price)

            elif k_shoe in ['Back','6']:
              print("\nReturning to previous page.")
              break
            else:
              print("\nSorry! We don't have this product available.")


        elif kid in ['Shades','iv']:
          while True:
            print("\n1.ROZIOR Kids Sunglasses\n2.Kasaer Polarized Sunglasses\n3.Hooper Full-Rim Sunglasses\n4.BabyMoon Panda-Shaped Sunglasses\n5.Back")
            print()
            k_shade=input("Enter you want to purchase: ")
            if k_shade in ['ROZIOR Kids Sunglasses','1']:
              product_name="\nROZIOR Kids Sunglasses, Black"
              price=333
              cart(product_name,price)

            elif k_shade in ['Kasear Polarized Sunglasses','2']:
              product_name="\nKasear Polarized Sunglasses, Multi-Color"
              price=1215
              cart(product_name,price)

            elif k_shade in ['Hooper Full-Rim Sunglasses','3']:
              product_name="\nHooper Full-Rim Sunglasses, Dark-Blue"
              price=600
              cart(product_name,price)

            elif k_shade in ['BabyMoon Panda-Shaped Sunglasses','4']:
              product_name="\nBabyMoon Panda-Shaped Sunglasses, Black & White"
              price=198
              cart(product_name,price)

            elif k_shade in ['Back']:
              print("\nReturning to previous page.")
              break
            else:
              print("\nSorry! We don't have this product available.")


        elif kid in ['Back','v']:
          print("\nReturning to previous page.")
          break
        else:
          print("\nInvalid characters. Enter your choice again.")



    elif age in ['Checkout','d']:
          checkout()

    elif age in ['Back','d']:
          print("\nReturning to previous page.")
          break

    else:
      print("\nInvalid characters. Enter your choice again.")



 elif category in ['Groceries','3']:
  while True:
    print("\n1.Vegitables\n2.Fruits\n3.Checkout\n4.Back")
    print()
    grocer=input("Enter your choice: ")
    if grocer in ['Vegitables','1']:
      while True:
        print("\nHere are vegitables\ni.Onions\nii.Potatos\niii.Brocoli\niv.Eggplant\nv.Cabbage\nvi.Tomatoes\nvii.Cucumber\nviii.Back")
        print()
        veg=input("Enter you want to purchase: ")
        if veg in ['Onions','i']:
          product_name="\nOnions, 1kg"
          price=30
          cart(product_name,price)

        elif veg in ['Potatoes','ii']:
          product_name="\nPotatoes, 1kg"
          price=20
          cart(product_name,price)

        elif veg in ['Brocoli','iii']:
          product_name="\nBrocoli, 1kg"
          price=12
          cart(product_name,price)

        elif veg in ['Eggplant','iv']:
          product_name="\nEggplant,1kg"
          price=20
          cart(product_name,price)

        elif veg in ['Cabbage','v']:
          product_name="\nCabbage, 1kg"
          price=40
          cart(product_name,price)

        elif veg in ['Tomatoes','vi']:
          product_name="\nTomatoes, 1kg"
          price=15
          cart(product_name,price)

        elif veg in ['Cucumber','vii']:
          product_name="\nCucumber, 1kg"
          price=30
          cart(product_name,price)

        elif veg in ['Back','viii']:
          print("\nReturning to previous page.")
          break
        else:
          print("\nSorry! We don't have this product available")


    elif grocer in ['Fruits','2']:
      while True:
        print("\nHere are fruits!\ni.Apples\nii.Mangoes\niii.Oranges\niv.Grapes\nv.Avocardos\nvi.Pineapples\nvii.Pomegranate\nviii.Back")
        print()
        fru=input("Enter you want to purchase: ")
        if fru in ['Apples','i']:
          product_name="\nApples, 1kg"
          price=110
          cart(product_name,price)

        elif fru in ['Mangoes','ii']:
          product_name="\nMangoes, 1kg"
          price=102
          cart(product_name,price)

        elif fru in ['Oranges','iii']:
          product_name="\nOranges, 1kg"
          price=80
          cart(product_name,price)

        elif fru in ['Grapes','iv']:
          product_name="\nGrapes, 1kg"
          price=90
          cart(product_name,price)

        elif fru in ['Avocardos','v']:
          product_name="\nAvocardos, 1kg"
          price=400
          cart(product_name,price)

        elif fru in ['Pineapples','vi']:
          product_name="\nPineapples, 1kg"
          price=60
          cart(product_name,price)

        elif fru in ['Pomegranate','vii']:
          product_name="\nPomegranate, 1kg"
          price=150
          cart(product_name,price)

        elif fru in ['Back','viii']:
          print("\nReturning to previous page.")
          break
        else:
          print("\nSorry! We don't have this product available.")

    elif grocer in ['Checkout','3']:
      checkout()

    elif grocer in ['Back','3']:
      print("\nReturning to previous page")
      break

    else:
      print("\nInvalid characters. Enter your choice again.")

 elif category in ['Checout','4']:
  checkout()

 elif category in ['Exit','5']:
  print("\nThank you for shopping with Amazon!!\n")
  print("Stay safe.")
  break

 else:
  print("Invalid characters. Enter your choice again.")
# Out:
# 		***Welcome to Amazon Online Shopping!!!***
#
# Do you have an account? (True/False): false
#
# Let's create one!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-5f4e403102ab> in <cell line: 0>()
#      70         authenticated = signin()
#      71     elif account_input == 'false':
# ---> 72         authenticated = signup()
#      73     else:
#      74         print("Invalid input. Please enter 'True' or 'False'.")
#
# <ipython-input-9-5f4e403102ab> in signup()
#      52   authentication = False
#      53   print("\nLet's create one!!!")
# ---> 54   email=input("Enter your email: ")
#      55   password=input("Enter your password: ")
#      56   re_password=input("Re-enter your password: ")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
